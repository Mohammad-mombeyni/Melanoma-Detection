# %%
! sudo apt-get update -qq
! sudo apt-get install y-megatools
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package y-megatools

# %%
# !apt-get update && apt-get install megatools -y
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
! megadl "https://mega.nz/file/XXpymSpJ#ahg78-8WZSRarsAWXq4FDt86QWLUttOt2S-rNhxDoaw"  # download file in mega
# Out:
# Downloaded dataset.zip

# %%
import zipfile

with zipfile.ZipFile('dataset.zip', 'r') as zip_ref :
    zip_ref.extractall('melanoma-dataset')

# %%
! pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8s-cls.pt')

# %%
model.train(
    data ='/content/melanoma-dataset',
    epochs = 100,
    imgsz = 240,
    batch =16,
    device = 0

)
# Out:
# Ultralytics 8.4.89 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.4.89 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8s-cls summary (fused): 30 layers, 5,077,762 parameters, 0 gradients, 12.4 GFLOPs
# train: /content/melanoma-dataset/train... found 10682 images in 2 classes ✅
# val: /content/melanoma-dataset/val... found 3562 images in 2 classes ✅
# test: None...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 422.0±198.5 MB/s, size: 6.4 KB)
# val: Scanning /content/melanoma-dataset/val... 3562 images, 0 corrupt: 100% ━━━━━━━━━━━━ 3562/3562 1.4Git/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 223/223 10.0it/s 22.4s
#                    all      0.966          1
# Speed: 0.1ms preprocess, 1.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/val
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7f6be09d8800>
# curves: []
# curves_results: []
# ...
