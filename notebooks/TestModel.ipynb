# %%
from ultralytics import YOLO

# %%
model = YOLO('best.pt')

# %%
result = model(r"H:\university\AI\projects\Melanoma Cencer detection\test Image\melanoma\10.jpeg")
# Out:
# image 1/1 H:\university\AI\projects\Melanoma Cencer detection\test Image\melanoma\10.jpeg: 256x256 Melanoma 1.00, NotMelanoma 0.00, 62.6ms
# Speed: 9.9ms preprocess, 62.6ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 256)

# %%
res = result[0]
res.show()
res.save(filename=r'H:\university\AI\projects\Melanoma Cencer detection\export1')
# Out:
# 'H:\\university\\AI\\projects\\Melanoma Cencer detection\\export1'

# %%
print(res.boxes)
# Out:
# None
